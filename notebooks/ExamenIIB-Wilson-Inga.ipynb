# %% [markdown]
# # Examen Final - Recuperación de Información
# **Fecha:** 28 de julio de 2025
# **Autor:** Wilson Inga
#
# ---
#
# ## Objetivo General
#
# Diseñar e implementar un sistema de Recuperación de Información (IR) que:
#
# a) Ingesta y preprocesa un corpus de documentos científicos (subset del 1% de arXiv).
# b) Implemente recuperación usando:
# - Modelo **TF–IDF**
# - Modelo **BM25**
# - Índice vectorial usando **FAISS** o **ChromaDB**
#
# c) Integre un módulo **RAG (Retrieval-Augmented Generation)** con un modelo de lenguaje.
# d) Evalúe la calidad de la recuperación comparando los resultados de cada modelo.

# %% [markdown]
# # 1. Carga del Corpus

# %%
import os
import pandas as pd
import kaggle

# Descargar el dataset
dataset = "Cornell-University/arxiv"
path = "../data/arxiv"

# Descargar el dataset si no existe
if not os.path.exists(path):
    os.makedirs(path)

    kaggle.api.dataset_download_files(dataset, path=path, unzip=True)
    print("Dataset descargado y descomprimido.")
else:
    print("El dataset ya existe en la ruta especificada.")
# Out:
# El dataset ya existe en la ruta especificada.

# %%
import json
import random

input_file = os.path.join(path, "arxiv-metadata-oai-snapshot.json")
output_file = os.path.join(path, "arxiv_sample_1_percent.jsonl")

# Contar líneas totales (puede tardar un poco)
with open(input_file, 'r', encoding='utf-8') as f:
    total_lines = sum(1 for _ in f)

# Número de muestras (1%)
sample_size = int(total_lines * 0.01)

# Elegir aleatoriamente los índices de las líneas a guardar
sample_indices = set(random.sample(range(total_lines), sample_size))

# Extraer solo esas líneas y guardarlas
with open(input_file, 'r', encoding='utf-8') as fin, open(output_file, 'w', encoding='utf-8') as fout:
    for i, line in enumerate(fin):
        if i in sample_indices:
            fout.write(line)

print(f"Guardado 1% ({sample_size} líneas) en '{output_file}'")
# Out:
# Guardado 1% (27923 líneas) en '../data/arxiv\arxiv_sample_1_percent.jsonl'

# %%
df_sample = pd.read_json(output_file, lines=True)
df_sample
# Out:
#                      id          submitter  \
# 0             0704.0015    Christian Stahn
# 1             0704.0046         Denes Petz
# 2             0704.0060   Carlos Bertulani
# 3             0704.0069     John Robertson
# 4             0704.0079   Stephen C. Power
# ...                 ...                ...
# 27918  solv-int/9712008    Ziad Maassarani
# 27919  solv-int/9801026     Yasuhiro Fujii
# 27920  solv-int/9807004  I. A. B. Strachan
# 27921  solv-int/9901001      Jeremy Schiff
# 27922  solv-int/9909014      David Fairlie
#
#                                                  authors  \
# 0                                        Christian Stahn
# 1                        I. Csiszar, F. Hiai and D. Petz
# 2      C.A. Bertulani, G. Cardella, M. De Napoli, G. ...
# 3                                      John W. Robertson
# 4      Stephen C. Power (Lancaster University), Baruc...
# ...                                                  ...
# 27918                   Z. Maassarani (Laval university)
# 27919                     Yasuhiro Fujii and Miki Wadati
# 27920                                     I.A.B.Strachan
# 27921                      Michael Fisher, Jeremy Schiff
# 27922                       D.B. Fairlie and A.N. Leznov
#
#                                                    title  \
# 0      Fermionic superstring loop amplitudes in the p...
# 1      A limit relation for entropy and channel capac...
# 2      Coulomb excitation of unstable nuclei at inter...
# 3      Dynamical Objects for Cohomologically Expandin...
# 4      Operator algebras associated with unitary comm...
# ...                                                  ...
# 27918                                     The XXC Models
# 27919  Correlation Functions of Finite XXZ model with...
# 27920  Degenerate Frobenius manifolds and the bi-Hami...
# 27921  The Camassa-Holm Equation: Conserved Quantitie...
# 27922  The General Solution of the Complex Monge-Amp\...
#
#                                                 comments  \
# 0      22 pages; signs and coefficients adjusted for ...
# 1                                   LATEX file, 11 pages
# 2      12 pages, 2 figures, accepted for publication ...
# 3                                               38 pages
# 4                                               38 pages
# ...                                                  ...
# 27918                                     6 pages, LaTeX
# 27919            16pages, LaTeX2e file, errors corrected
# 27920                                    28 pages, LaTeX
# 27921                                     8 pages, LaTeX
# 27922                        13 pages, latex, no figures
#
#                             journal-ref                             doi  \
# 0                    JHEP 0705:034,2007   10.1088/1126-6708/2007/05/034
# 1      J. Math. Phys. 48(2007), 092102.               10.1063/1.2779138
# 2           Phys.Lett.B650:233-238,2007  10.1016/j.physletb.2007.05.029
# 3                                  None                            None
# 4                                  None                            None
# ...                                 ...                             ...
# 27918  Phys. Lett. A 244 (1998) 160-164   10.1016/S0375-9601(98)00322-3
# 27919                              None                            None
# 27920   J. Math. Phys. 40, 5058 (1999);                10.1063/1.533015
# 27921                              None   10.1016/S0375-9601(99)00466-1
# 27922                              None     10.1088/0305-4470/33/25/307
#
#              report-no                               categories license  \
# 0                 None                                   hep-th    None
# 1                 None                   quant-ph cs.IT math.IT    None
# 2                 None                                  nucl-th    None
# 3                 None                                  math.DS    None
# 4                 None                                  math.OA    None
# ...                ...                                      ...     ...
# 27918  LAVAL-PHY-27/97  solv-int cond-mat math.QA nlin.SI q-alg    None
# 27919             None         solv-int cond-mat hep-th nlin.SI    None
# 27920             None                         solv-int nlin.SI    None
# 27921             None                         solv-int nlin.SI    None
# 27922             None                         solv-int nlin.SI    None
#
#                                                 abstract  \
# 0        The pure spinor formulation of the ten-dimen...
# 1        In a quantum mechanical model, Diosi, Feldma...
# 2        We investigate the Coulomb excitation of low...
# 3        The goal of this paper is to construct invar...
# 4        We define nonselfadjoint operator algebras w...
# ...                                                  ...
# 27918    A class of recently introduced multi-states ...
# 27919    The finite XXZ model with boundaries is cons...
# 27920    The bi-Hamiltonian structure of certain mult...
# 27921    Using a Miura-Gardner-Kruskal type construct...
# 27922    A general solution to the Complex Monge-Amp\...
#
#                                                 versions update_date  \
# 0      [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2009-11-13
# 1      [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2009-11-13
# 2      [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-11-26
# 3      [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2010-01-08
# 4      [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2007-05-23
# ...                                                  ...         ...
# 27918  [{'version': 'v1', 'created': 'Thu, 11 Dec 199...  2009-10-30
# 27919  [{'version': 'v1', 'created': 'Wed, 28 Jan 199...  2007-05-23
# 27920  [{'version': 'v1', 'created': 'Wed, 8 Jul 1998...  2020-12-16
# 27921  [{'version': 'v1', 'created': 'Mon, 4 Jan 1999...  2009-10-31
# 27922  [{'version': 'v1', 'created': 'Thu, 16 Sep 199...  2019-08-21
#
#                                           authors_parsed
# 0                                 [[Stahn, Christian, ]]
# 1          [[Csiszar, I., ], [Hiai, F., ], [Petz, D., ]]
# 2      [[Bertulani, C. A., ], [Cardella, G., ], [De N...
# 3                               [[Robertson, John W., ]]
# 4      [[Power, Stephen C., , Lancaster University], ...
# ...                                                  ...
# 27918             [[Maassarani, Z., , Laval university]]
# 27919            [[Fujii, Yasuhiro, ], [Wadati, Miki, ]]
# 27920                           [[Strachan, I. A. B., ]]
# 27921          [[Fisher, Michael, ], [Schiff, Jeremy, ]]
# 27922            [[Fairlie, D. B., ], [Leznov, A. N., ]]
#
# [27923 rows x 14 columns]

# %% [markdown]
# #  Implementación de la Arquitectura

# %% [markdown]
# # 1. Preprocemiento del Corpus

# %%
import json
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords

# Descarga de recursos NLTK
nltk.download('stopwords')
stop_words = set(stopwords.words("english"))

# Preprocesamiento
def preprocess_text(title, abstract):
    text = f"{title} {abstract}".lower()
    text = re.sub(r'[^\w\s]', '', text)
    tokens = text.split()
    tokens = [t for t in tokens if t not in stop_words]
    return ' '.join(tokens)

# Cargar corpus desde archivo JSONL
def load_corpus(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        corpus = [json.loads(line) for line in f]
    return corpus

# Cargar datos
file_path = "../data/arxiv/arxiv_sample_1_percent.jsonl"  
corpus = load_corpus(file_path)
df_sample = pd.DataFrame(corpus)

# Aplicar preprocesamiento
df_sample['Preprocesado'] = df_sample.apply(
    lambda row: preprocess_text(row['title'], row['abstract']), axis=1
)

# Crear columna con texto combinado original (sin preprocesar)
df_sample['Original'] = df_sample['title'] + " " + df_sample['abstract']

# Mostrar primeras filas con original y preprocesado
df_sample[['Original', 'Preprocesado']].head(25)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\wil_s\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                              Original  \
# 0   Fermionic superstring loop amplitudes in the p...
# 1   A limit relation for entropy and channel capac...
# 2   Coulomb excitation of unstable nuclei at inter...
# 3   Dynamical Objects for Cohomologically Expandin...
# 4   Operator algebras associated with unitary comm...
# 5   Interface dynamics of microscopic cavities in ...
# 6   Specific heat and bimodality in canonical and ...
# 7   Isospin breaking in the yield of heavy meson p...
# 8   Remnant evolution after a carbon-oxygen white ...
# 9   Direct Theorems in the Theory of Approximation...
# 10  Extra dimensions and Lorentz invariance violat...
# 11  Low mass visual binaries in the solar neighbou...
# 12  Renewals for exponentially increasing lifetime...
# 13  An invariance principle for semimartingale ref...
# 14  Inapproximability of Maximum Weighted Edge Bic...
# 15  Self-diffusion and Interdiffusion in Al80Ni20 ...
# 16  Substructures in WINGS clusters   We search fo...
# 17  About curvature, conformal metrics and warped ...
# 18  Necessary optimality conditions for the calcul...
# 19  Convergence of a finite volume scheme for the ...
# 20  Vortex Molecular Crystal and Vortex Plastic Cr...
# 21  On packet lengths and overhead for random line...
# 22  Universal Source Coding for Monotonic and Fast...
# 23  Criteria in the Selection of Target Events for...
# 24  Toric symplectic ball packing   We define and ...
#
#                                          Preprocesado
# 0   fermionic superstring loop amplitudes pure spi...
# 1   limit relation entropy channel capacity per un...
# 2   coulomb excitation unstable nuclei intermediat...
# 3   dynamical objects cohomologically expanding ma...
# 4   operator algebras associated unitary commutati...
# 5   interface dynamics microscopic cavities water ...
# 6   specific heat bimodality canonical grand canon...
# 7   isospin breaking yield heavy meson pairs ee an...
# 8   remnant evolution carbonoxygen white dwarf mer...
# 9   direct theorems theory approximation banach sp...
# 10  extra dimensions lorentz invariance violation ...
# 11  low mass visual binaries solar neighbourhood c...
# 12  renewals exponentially increasing lifetimes ap...
# 13  invariance principle semimartingale reflecting...
# 14  inapproximability maximum weighted edge bicliq...
# 15  selfdiffusion interdiffusion al80ni20 melts si...
# 16  substructures wings clusters search characteri...
# 17  curvature conformal metrics warped products co...
# 18  necessary optimality conditions calculus varia...
# 19  convergence finite volume scheme incompressibl...
# 20  vortex molecular crystal vortex plastic crysta...
# 21  packet lengths overhead random linear coding e...
# 22  universal source coding monotonic fast decayin...
# 23  criteria selection target events planetary mic...
# 24  toric symplectic ball packing define solve tor...

# %% [markdown]
# # 2. Indexación

# %% [markdown]
# ## TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer_tfidf = TfidfVectorizer()
tfidf_matrix = vectorizer_tfidf.fit_transform(df_sample['Preprocesado'])

print("TF–IDF indexado. Forma de la matriz:", tfidf_matrix.shape)
# Out:
# TF–IDF indexado. Forma de la matriz: (27923, 123456)

# %% [markdown]
# ## BM25

# %%
from rank_bm25 import BM25Okapi

# Tokenizar corpus preprocesado
tokenized_corpus = [doc.split() for doc in df_sample['Preprocesado']]

# Crear índice BM25
bm25 = BM25Okapi(tokenized_corpus)

print("BM25 indexado. Número de documentos:", len(tokenized_corpus))
# Out:
# BM25 indexado. Número de documentos: 27923

# %% [markdown]
# ## FAISS

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# Cargar modelo de embeddings
model = SentenceTransformer("all-MiniLM-L6-v2")

# Obtener embeddings
embeddings = model.encode(df_sample['Preprocesado'], convert_to_numpy=True)

# Crear índice FAISS
index = faiss.IndexFlatL2(embeddings.shape[1])  # Distancia L2
index.add(embeddings)

print("FAISS indexado. Total vectores:", index.ntotal)
# Out:
# FAISS indexado. Total vectores: 27923

# %%
# Guardar los IDs de los documentos
doc_ids = df_sample['id'].tolist()

# %% [markdown]
# # 3. Recuperación

# %% [markdown]
# ## 3.1. Búsqueda con TF-IDF

# %%
def search_tfidf(query, top_k=10):
    query_proc = preprocess_text(query, "")
    q_vec = vectorizer_tfidf.transform([query_proc])
    scores = tfidf_matrix @ q_vec.T
    top_indices = scores.toarray().ravel().argsort()[-top_k:][::-1]
    return df_sample.iloc[top_indices][['id', 'title', 'abstract']]

# %% [markdown]
# ## 3.2. Búsqueda con BM25

# %%
def search_bm25(query, top_k=10):
    query_proc = preprocess_text(query, "")
    query_tokens = query_proc.split()
    scores = bm25.get_scores(query_tokens)
    top_indices = np.argsort(scores)[-top_k:][::-1]
    return df_sample.iloc[top_indices][['id', 'title', 'abstract']]

# %% [markdown]
# ## 3.3. Búsqueda con FAISS

# %%
def search_faiss(query, top_k=10):
    query_proc = preprocess_text(query, "")
    query_embed = model.encode([query_proc])
    _, top_indices = index.search(query_embed, top_k)
    return df_sample.iloc[top_indices[0]][['id', 'title', 'abstract']]

# %% [markdown]
# ## 3.4. Comparación de modelos

# %%
# Leer queries.txt
with open("../data/arxiv/queries.txt", "r", encoding="utf-8") as f:
    queries = [line.strip() for line in f.readlines()]

# %% [markdown]
# ### Tabla Comparativa

# %%
import pandas as pd

def rank_overlap(list1, list2):
    return len(set(list1) & set(list2))

# Inicializar lista para los resultados
results_comparison = []

# Evaluar cada consulta
for query in queries:
    tfidf_ids = search_tfidf(query)['id'].tolist()
    bm25_ids = search_bm25(query)['id'].tolist()
    faiss_ids = search_faiss(query)['id'].tolist()

    results_comparison.append({
        "Query": query,
        "TF–IDF vs BM25": rank_overlap(tfidf_ids, bm25_ids),
        "TF–IDF vs FAISS": rank_overlap(tfidf_ids, faiss_ids),
        "BM25 vs FAISS": rank_overlap(bm25_ids, faiss_ids)
    })

# Crear DataFrame comparativo
df_comparativa = pd.DataFrame(results_comparison)
# Mostrar tabla comparativa
display(df_comparativa)
# Guardar DataFrame comparativo
df_comparativa.to_csv("../data/arxiv/comparative_results.csv", index=False)
# Out:
#                                    Query  TF–IDF vs BM25  TF–IDF vs FAISS  \
# 0     diphoton production cross sections               5                4
# 1                 quantum chromodynamics               3                1
# 2                      higgs boson decay               6                3
# 3  machine learning for particle physics               2                1
# 4                   top quark production               7                6
#
#    BM25 vs FAISS
# 0              3
# 1              2
# 2              5
# 3              2
# 4              5

# %% [markdown]
# # 4. RAG

# %% [markdown]
# ## 4.1. Instalación y carga del modelo

# %%
import os
from dotenv import load_dotenv

# Cargar las variables de entorno desde .env
load_dotenv()

# Obtener la clave desde la variable de entorno
api_key = os.getenv("GEMINI_API_KEY")

# %%
import google.generativeai as genai

# Cargar tu API key
import os
from dotenv import load_dotenv
load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")
genai.configure(api_key=api_key)

# Listar los modelos disponibles
for m in genai.list_models():
    print(m.name)
# Out:
# models/embedding-gecko-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-2.5-flash-lite
# models/embedding-001
# models/text-embedding-004
# models/gemini-embedding-exp-03-07
# models/gemini-embedding-exp
# models/gemini-embedding-001
# models/aqa
# models/imagen-3.0-generate-002
# models/imagen-4.0-generate-preview-06-06
# models/imagen-4.0-ultra-generate-preview-06-06
# models/veo-2.0-generate-001
# models/veo-3.0-generate-preview
# models/gemini-2.5-flash-preview-native-audio-dialog
# models/gemini-2.5-flash-exp-native-audio-thinking-dialog
# models/gemini-2.0-flash-live-001
# models/gemini-live-2.5-flash-preview
# models/gemini-2.5-flash-live-preview

# %% [markdown]
# ## 4.2. Función RAG

# %%
# Modelo de embeddings (FAISS)
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")

# Modelo generativo (Gemini)
genai_model = genai.GenerativeModel("gemini-1.5-flash")

# %%
def generate_rag_with_gemini(query, top_k=3):
    query_proc = preprocess_text(query, "")
    
    # Usar el modelo de embeddings correctamente
    query_embed = embedding_model.encode([query_proc])
    _, top_indices = index.search(query_embed, top_k)
    results = df_sample.iloc[top_indices[0]]

    # Construir el contexto con los abstracts
    context = ""
    for _, row in results.iterrows():
        context += f"Title: {row['title']}\nAbstract: {row['abstract']}\n\n"

    # Crear el prompt para Gemini
    prompt = (
        f"Context:\n{context}\n"
        f"Question: Based on the above scientific articles, summarize the main ideas and explain why they are relevant to the query: \"{query}\""
    )

    # Generar respuesta usando Gemini
    response = genai_model.generate_content(prompt)

    return response.text, results[['id', 'title']]

# %%
respuesta, docs = generate_rag_with_gemini("machine learning for particle physics")
print("Respuesta generada:")
print(respuesta)
display(docs)
# Out:
# Respuesta generada:
# The three abstracts highlight different applications of machine learning (ML) within particle physics, demonstrating its growing relevance:
#
# * **Abstract 1:** Focuses on using neural networks to improve Monte Carlo integration in phase space, a crucial step in simulating particle collisions. This is relevant because efficient phase space integration is essential for accurately predicting experimental outcomes and comparing them to theoretical models.  The ML approach offers a speed and efficiency advantage over traditional methods like VEGAS, particularly for complex scenarios.
#
# * **Abstract 2:** Provides a broad overview of ML applications in neutrino physics.  This is significant because neutrinos are notoriously difficult to detect and analyze, and ML techniques are proving vital for tackling challenges like background noise reduction, signal extraction, and dealing with limited statistics. This abstract emphasizes the importance of understanding both the benefits and limitations of ML in this context.
#
# * **Abstract 3:** Shows how Bayesian neural networks can efficiently model the complex relationships between parameters in supersymmetry (SUSY) models and their observable predictions. SUSY is a prominent theory beyond the Standard Model, and this work demonstrates ML's ability to significantly speed up the computationally intensive process of exploring the vast parameter space of such models, thus accelerating the search for new physics.
#
# In summary, these abstracts showcase the utility of machine learning across diverse aspects of particle physics.  They illustrate how ML can:
#
# * **Improve simulation efficiency:** By accelerating computationally expensive tasks like phase space integration.
# * **Enhance data analysis:** By improving signal extraction and background rejection in experiments.
# * **Accelerate theoretical model exploration:** By efficiently mapping complex theoretical models to their observable predictions.
#
# The relevance to the query "machine learning for particle physics" is clear: these papers provide concrete examples of how ML is being applied to solve pressing problems and improve the efficiency of research in this field, indicating a rapidly expanding and impactful role for ML in advancing our understanding of fundamental particles and forces.
#                id                                              title
# 10453  1810.11509  Neural Network-Based Approach to Phase Space I...
# 13213  2008.01242  A Review on Machine Learning for Neutrino Expe...
# 13093  2007.04506  Bayesian Neural Networks for Fast SUSY Predict...

# %% [markdown]
# # 5. Evaluación

# %% [markdown]
# ## 5.1. Comparar documentos recuperados por los 3 modelos

# %%
def compare_models(query, top_k=10):
    tfidf_docs = search_tfidf(query, top_k)['id'].tolist()
    bm25_docs = search_bm25(query, top_k)['id'].tolist()
    faiss_docs = search_faiss(query, top_k)['id'].tolist()

    common_docs = set(tfidf_docs) & set(bm25_docs) & set(faiss_docs)
    
    print("Query:", query)
    print(f"\nDocumentos en común entre los tres modelos ({len(common_docs)}):")
    print(common_docs)

    print("\nOrdenamiento de IDs:")
    print("TF–IDF:", tfidf_docs)
    print("BM25  :", bm25_docs)
    print("FAISS :", faiss_docs)

    return tfidf_docs, bm25_docs, faiss_docs

# %% [markdown]
# ## 5.2. Medir similitud entre rankings

# %%
def count_rank_overlap(a, b):
    return len(set(a) & set(b))

def evaluate_rank_overlap(query):
    tfidf_docs, bm25_docs, faiss_docs = compare_models(query)

    print(f"\nCoincidencias top-10:")
    print(f"TF–IDF vs BM25 : {count_rank_overlap(tfidf_docs, bm25_docs)}")
    print(f"TF–IDF vs FAISS: {count_rank_overlap(tfidf_docs, faiss_docs)}")
    print(f"BM25   vs FAISS: {count_rank_overlap(bm25_docs, faiss_docs)}")

# %%
print(f"embedding_model type: {type(embedding_model)}")
print(f"genai_model type: {type(genai_model)}")
# Out:
# embedding_model type: <class 'sentence_transformers.SentenceTransformer.SentenceTransformer'>
# genai_model type: <class 'google.generativeai.generative_models.GenerativeModel'>

# %% [markdown]
# ## 5.3. Evaluar la respuesta generada con RAG

# %%
def evaluate_rag(query):
    response, supporting_docs = generate_rag_with_gemini(query)

    print("Respuesta generada con RAG:")
    print(response)

    print("\nDocumentos usados:")
    display(supporting_docs)

# %%
# Evaluar RAG
evaluate_rag(query)
# Out:
# Respuesta generada con RAG:
# These three abstracts highlight different applications of machine learning (ML) within particle physics, demonstrating its growing importance in addressing complex computational challenges:
#
# * **Abstract 1:** Focuses on using neural networks to improve Monte Carlo simulations for phase space integration.  This is crucial for accurately calculating probabilities of particle interactions and decay rates, a fundamental aspect of particle physics analyses.  The relevance to the query is the demonstration of ML's ability to significantly speed up and improve the efficiency of a core computational task in the field.
#
# * **Abstract 2:** Provides a broader overview of ML's impact on neutrino physics.  It emphasizes how ML tackles challenges like large backgrounds, elusive signals, and limited data – common problems in experimental particle physics.  The relevance is in showcasing the widespread adoption of ML across various experimental aspects of neutrino physics, addressing fundamental limitations in data analysis.
#
# * **Abstract 3:** Shows the application of Bayesian neural networks to predict properties of supersymmetric models (a theory beyond the Standard Model). This demonstrates the use of ML to efficiently explore vast parameter spaces of theoretical models, enabling faster and more thorough testing of new physics theories. The relevance is in demonstrating ML's capacity to handle high-dimensional data and expedite the theoretical modeling crucial for guiding experimental searches.
#
#
# In essence, these abstracts collectively illustrate how machine learning is revolutionizing particle physics.  It's used to:
#
# * **Improve simulation efficiency:** speeding up computationally intensive tasks like Monte Carlo simulations.
# * **Enhance data analysis:** overcoming challenges in experimental data analysis, such as background noise and low statistics.
# * **Accelerate theoretical modeling:** efficiently exploring complex theoretical models and making predictions for experimental verification.
#
# The query "machine learning for particle physics" is directly addressed by these articles, which show diverse and impactful applications across simulation, experiment, and theory, highlighting the transformative potential of ML in this field.
#
#
# Documentos usados:
#                id                                              title
# 10453  1810.11509  Neural Network-Based Approach to Phase Space I...
# 13213  2008.01242  A Review on Machine Learning for Neutrino Expe...
# 13093  2007.04506  Bayesian Neural Networks for Fast SUSY Predict...
